# %%
import requests

# %%
import os 
from PIL import Image
from IPython.display import IFrame
import json
import pandas as pd
import numpy as np

# %%
url = "http://api.exchangeratesapi.io/v1/latest?base=EUR&access_key=762a34294ac4e8b18e63006d12d888af"  #Make sure to change ******* to your API key.
html_data = requests.get(url)

# %%
html_data.status_code
# Out:
# 200

# %%
print(html_data.request.headers)
# Out:
# {'User-Agent': 'python-requests/2.28.1', 'Accept-Encoding': 'gzip, deflate, br', 'Accept': '*/*', 'Connection': 'keep-alive'}

# %%
print(html_data.request.body)
# Out:
# None

# %%
html_data.headers
# Out:
# {'Date': 'Tue, 15 Aug 2023 07:01:59 GMT', 'Content-Type': 'application/json; Charset=UTF-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'x-apilayer-transaction-id': '7d919627-cec4-47a7-8270-ca64030d4379', 'access-control-allow-methods': 'GET, HEAD, POST, PUT, PATCH, DELETE, OPTIONS', 'access-control-allow-origin': '*', 'x-request-time': '0.010', 'CF-Cache-Status': 'DYNAMIC', 'Report-To': '{"endpoints":[{"url":"https:\\/\\/a.nel.cloudflare.com\\/report\\/v3?s=LNpLgIgYbXPcpsvjMlQd9yLdh2hRofYEEfwTIIUZhA9QGZcEO5K%2Fqu1vQYlOGtvrZHhJcDm8j1wJqTREFfPYt4%2BmPqhr89XhDJlWPdBqZkUXyf2xKrS4dr7yaA4ShHWDsTE21TP6OCplJ5PbZe297E5rfbRb"}],"group":"cf-nel","max_age":604800}', 'NEL': '{"success_fraction":0,"report_to":"cf-nel","max_age":604800}', 'Server': 'cloudflare', 'CF-RAY': '7f6f91c27ea93a87-BOM', 'Content-Encoding': 'gzip'}

# %%
html_data.text
# Out:
# '{"success":true,"timestamp":1692082863,"base":"EUR","date":"2023-08-15","rates":{"AED":4.01213,"AFN":92.2123,"ALL":104.131308,"AMD":424.616988,"ANG":1.975388,"AOA":902.794058,"ARS":382.224502,"AUD":1.682371,"AWG":1.966171,"AZN":1.919019,"BAM":1.95861,"BBD":2.213085,"BDT":119.972128,"BGN":1.958296,"BHD":0.411725,"BIF":3114.468441,"BMD":1.092317,"BND":1.48433,"BOB":7.573936,"BRL":5.422271,"BSD":1.096073,"BTC":3.7237773e-5,"BTN":90.920079,"BWP":14.861731,"BYN":2.767045,"BYR":21409.416866,"BZD":2.20929,"CAD":1.470363,"CDF":2676.176905,"CHF":0.958055,"CLF":0.034052,"CLP":939.589534,"CNY":7.92902,"COP":4412.961436,"CRC":586.552287,"CUC":1.092317,"CUP":28.946405,"CVE":110.425453,"CZK":24.068006,"DJF":195.155356,"DKK":7.451712,"DOP":62.340584,"DZD":148.397848,"EGP":33.771758,"ERN":16.384758,"ETB":60.456546,"EUR":1,"FJD":2.466397,"FKP":0.860639,"GBP":0.859304,"GEL":2.850656,"GGP":0.860639,"GHS":12.385884,"GIP":0.860639,"GMD":66.249548,"GNF":9421.517393,"GTQ":8.613516,"GYD":229.3111,"HKD":8.5
# ...

# %%
data = json.loads(html_data.text)
data
# Out:
# {'success': True,
#  'timestamp': 1692082863,
#  'base': 'EUR',
#  'date': '2023-08-15',
#  'rates': {'AED': 4.01213,
#   'AFN': 92.2123,
#   'ALL': 104.131308,
#   'AMD': 424.616988,
#   'ANG': 1.975388,
#   'AOA': 902.794058,
#   'ARS': 382.224502,
#   'AUD': 1.682371,
#   'AWG': 1.966171,
#   'AZN': 1.919019,
#   'BAM': 1.95861,
#   'BBD': 2.213085,
#   'BDT': 119.972128,
#   'BGN': 1.958296,
#   'BHD': 0.411725,
#   'BIF': 3114.468441,
#   'BMD': 1.092317,
#   'BND': 1.48433,
#   'BOB': 7.573936,
#   'BRL': 5.422271,
#   'BSD': 1.096073,
#   'BTC': 3.7237773e-05,
#   'BTN': 90.920079,
#   'BWP': 14.861731,
#   'BYN': 2.767045,
#   'BYR': 21409.416866,
#   'BZD': 2.20929,
#   'CAD': 1.470363,
#   'CDF': 2676.176905,
#   'CHF': 0.958055,
#   'CLF': 0.034052,
#   'CLP': 939.589534,
#   'CNY': 7.92902,
#   'COP': 4412.961436,
#   'CRC': 586.552287,
#   'CUC': 1.092317,
#   'CUP': 28.946405,
#   'CVE': 110.425453,
#   'CZK': 24.068006,
#   'DJF': 195.155356,
#   'DKK': 7.451712,
# ...

# %%
dataframe = pd.DataFrame(data)
dataframe
# Out:
#      success   timestamp base        date        rates
# AED     True  1692082863  EUR  2023-08-15     4.012130
# AFN     True  1692082863  EUR  2023-08-15    92.212300
# ALL     True  1692082863  EUR  2023-08-15   104.131308
# AMD     True  1692082863  EUR  2023-08-15   424.616988
# ANG     True  1692082863  EUR  2023-08-15     1.975388
# ..       ...         ...  ...         ...          ...
# YER     True  1692082863  EUR  2023-08-15   273.461600
# ZAR     True  1692082863  EUR  2023-08-15    20.839063
# ZMK     True  1692082863  EUR  2023-08-15  9832.164540
# ZMW     True  1692082863  EUR  2023-08-15    21.153543
# ZWL     True  1692082863  EUR  2023-08-15   351.725689
#
# [170 rows x 5 columns]

# %%
final_df = dataframe.drop(columns = {'success','timestamp', 'base', 'date'})
final_df
# Out:
#            rates
# AED     4.012130
# AFN    92.212300
# ALL   104.131308
# AMD   424.616988
# ANG     1.975388
# ..           ...
# YER   273.461600
# ZAR    20.839063
# ZMK  9832.164540
# ZMW    21.153543
# ZWL   351.725689
#
# [170 rows x 1 columns]

# %%
a = final_df.sort_values(by='rates', ascending = False)
a
# Out:
#             rates
# VEF  3.373600e+06
# IRR  4.620502e+04
# VND  2.613915e+04
# STD  2.260876e+04
# SLL  2.157326e+04
# ..            ...
# KWD  3.361280e-01
# XAG  4.836500e-02
# CLF  3.405200e-02
# XAU  5.740000e-04
# BTC  3.723777e-05
#
# [170 rows x 1 columns]
